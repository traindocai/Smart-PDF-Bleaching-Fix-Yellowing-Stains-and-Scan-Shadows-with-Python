# %% [markdown]
# <a href="https://colab.research.google.com/github/traindocai/Smart-PDF-Bleaching-Fix-Yellowing-Stains-and-Scan-Shadows-with-Python/blob/main/Smart_PDF_Bleaching_Fix_Yellowing%2C_Stains%2C_and_Scan_Shadows_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lesson 1: Launching your AI Notebook**

# %% [markdown]
# 🚀 **Step 1: Testing Python**
#
# **Instructions:**
#
# * Click into the first empty cell below.
#
# * Type exactly: `'python'`
#
# * Press the Play button (the circle with a triangle).
#
# ⚠️ Note: In Python, text is called a **String**. To tell the computer you are typing text, you must wrap the word in quotes: `'python'`
#
# 🔄 Troubleshooting: If the notebook stops responding, simply go to the top menu bar and follow this path: Runtime > Restart session. After you restart the session, you will need to re-run your code cells (starting from the top).

# %% [markdown]
# <details>
# <summary><b>Click here to see the solution for Step 1</b></summary>
#
# ```python
# 'python'
#
# Expected Output: python

# %% [markdown]
# 📦 **Step 2: Writing a Variable**
#
# Now we will store text inside a "container" so we can use it later.
#
# **Instructions:**
#
# In the next cell, type the following: `text = 'Python is easy to learn.'`
#
# Press the Play button.
#
# 💡 Key Concepts:
#
# * `'Python is easy to learn.'` is a **String**; it is your data. This is a Python **Object**.
#
# * `text` is the label; it is a variable. A **variable** is like a container that stores your data so the computer remembers it. A variable is a reference to an object.
#
# * The equal sign (`=`) in Python doesn't mean 'is the same as' like in math; it is an **assignment operator**. It tells the computer: 'Take this data on the right and put it into the container on the left.'
#
# * **Syntax Errors**: Ensure you aren't using "curly quotes" from Word; Python only likes straight quotes `' '`.

# %% [markdown]
# <details>
# <summary><b>Click here to see the solution for Step 2</b></summary>
#
# ```python
# text = 'Python is easy to learn.'

# %% [markdown]
# 📢 **Step 3: The Print Function**
#
# **Instructions:**
#
# In the next cell, type `print(text)`
#
# Press the Play button.
#
#
#
#
# **What happened?**
#
# You just used the **Function** `print()`. In Python, a function is a named, reusable block of code designed to perform a specific task. The `print()` function’s job is to display information on your screen.

# %% [markdown]
# <details>
# <summary><b>Click here to see the solution for Step 3</b></summary>
#
# ```python
# print(text)
#
# Expected Output: Python is easy to learn.

# %% [markdown]
# ⚡ **Step 4: Create Your Own Variable**
#
# **Instructions:**
#
# Click the `+ Code` button at the top left of your screen to open a fresh cell.
# Type the following two lines of code exactly as shown:
#
# `text = 'Cleaning PDFs with AI'`
#
# `print(text)`
#
# Press the Play button.

# %% [markdown]
# <details>
# <summary><b>Click here to see the solution for Step 4</b></summary>
#
# ```python
# text = 'Cleaning PDFs with AI'
# print(text)
#
# Expected Output: Cleaning PDFs with AI
